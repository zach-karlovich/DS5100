# %% [markdown]
# # M14 Notes

# %% [markdown]
# ## Business
#
# - No office hours this week
# - Last day of class is optional (office hours)

# %% [markdown]
# ## Use Markdown for pasting code

# %% [raw]
# ```python
#
# print("Hello, World!")
#
# ```

# %% [markdown]
# ```python
#
# print("Hello, World!")
#
# ```

# %% [markdown]
# ## Hints
#
# Rolling a die is just sampling with replacement using weights.
#
# - See the `.sample()` method for data frames in Pandas.

# %% [markdown]
# Results should look like this:
#
# ![image.png](attachment:619e297d-052d-4494-a69d-b11af6e244c7.png)

# %% [markdown]
# Permutations should look like this:
#
# ![image.png](attachment:8931a84f-64c7-449c-9bc7-fed6794b523a.png)
#
# The index can be converted into a list of concatenated characters.
#
# ![image.png](attachment:e72e4147-994a-4569-96ac-c3a75e8eab93.png)

# %% [markdown]
# Use a set operation to get the number of words generated in Scenario 3.
#
# - Difference, or `set1.intersection(set2)`
